# %% [markdown]
# <a href="https://colab.research.google.com/github/HienNguyenMinh/ImageProcessing/blob/main/ImportImagesToColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall gdown -y && pip install gdown
#Create a folder "Images" on Colab
# !rm -rf /content/Images
# !mkdir Images
#Down load Images from google drive link to the Colab folder
# !gdown --folder https://drive.google.com/drive/folders/1w9QCEQ_ShE2n3BlBqvyNvEZXYmGi6t2s?usp=share_link -O /content/Images
# Out:
# Found existing installation: gdown 4.6.2
# Uninstalling gdown-4.6.2:
#   Successfully uninstalled gdown-4.6.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Using cached gdown-4.6.2-py3-none-any.whl (14 kB)
# ...
# Retrieving folder list
# Processing file 1_UGmle7TFwaGRqFo4-17Xhbi-YRfbN4u earth1.tif
# Processing file 1YFfpDJ57K4qX-lqZLAqcyon_14MijTQp earth2.tif
# Processing file 1JIM89Bz-cl_E5u0f3Mnyke7f-bDv2C4A Image_Subtraction_with_contrast.jpg
# Processing file 1KDboNovdfOPooB0HhEi8QVXcFHegJd-d Image_Subtraction.jpg
# Processing file 1bl0iPtJ29nTtDZfisSIFT-tPi2OIU4gV L5_1_Image_Subtraction.m
# Processing file 1e2MyTfmu-7Y_Vdx3dpqfzsrgrvkoV-T9 L5_2_Image_Comparison.m
# Processing file 1va-a-8j9KPmpnUMaRlR9myGHTAUQ5r2N L5_3_Image_Averaging.m
# Processing file 1s40kIiVUK5g-w5cuFhbOEwZ709SjxDLz live.jpg
# Processing file 1HOpUBXHbxAbkRjuQB9TnWX1QBl-Dt1W9 Mask_Compasion_diff.png
# ...
